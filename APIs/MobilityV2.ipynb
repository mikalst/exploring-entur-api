# %% [markdown]
# # Mobility V2 API

# %% [markdown]
# Currently we offer data from a number of citybike and scooter operators in several Norwegian cities.
#
# All of our data is served in version 2.2 of the General Bikeshare Feed Specification (GBFS) format which is a standardized data feed for micro-mobility systems.

# %%
import requests as rq
import json
import pandas as pd
from pprint import pprint

# %%
r = rq.get("https://api.entur.io/mobility/v2/gbfs")
pprint(json.loads(r.content))
# Out:
# {'systems': [{'id': 'voioslo',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/voioslo/gbfs'},
#              {'id': 'voitrondheim',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/voitrondheim/gbfs'},
#              {'id': 'limeoslo',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/limeoslo/gbfs'},
#              {'id': 'boltoslo',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltoslo/gbfs'},
#              {'id': 'boltlillestrom',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltlillestrom/gbfs'},
#              {'id': 'boltfredrikstad',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltfredrikstad/gbfs'},
#              {'id': 'boltbergen',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltbergen/gbfs'},
#              {'id': 'boltsarpsborg',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltsarpsborg/gbfs'},
#              {'id': 'boltdrammen',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltdrammen/gbfs'},
#              {'id': 'boltgjovik',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltgjovik/gbfs'},
#              {'id': 'bolthamar',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/bolthamar/gbfs'},
#              {'id': 'boltlillehammer',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/boltlillehammer/gbfs'},
#              {'id': 'zvipptrondheim',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/zvipptrondheim/gbfs'},
#              {'id': 'oslobysykkel',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/oslobysykkel/gbfs'},
#              {'id': 'bergenbysykkel',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/bergenbysykkel/gbfs'},
#              {'id': 'trondheimbysykkel',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/trondheimbysykkel/gbfs'},
#              {'id': 'kolumbusbysykkel',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/kolumbusbysykkel/gbfs'},
#              {'id': 'lillestrombysykkel',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/lillestrombysykkel/gbfs'},
#              {'id': 'drammenbysykkel',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/drammenbysykkel/gbfs'},
#              {'id': 'tierasane',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierasane/gbfs'},
#              {'id': 'tierasker',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierasker/gbfs'},
#              {'id': 'tierbaerum',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierbaerum/gbfs'},
#              {'id': 'tierbergen',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierbergen/gbfs'},
#              {'id': 'tierdrammen',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierdrammen/gbfs'},
#              {'id': 'tierlillestrom',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierlillestrom/gbfs'},
#              {'id': 'tierlorenskog',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierlorenskog/gbfs'},
#              {'id': 'tiernamsos',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tiernamsos/gbfs'},
#              {'id': 'tieroslo',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tieroslo/gbfs'},
#              {'id': 'tierski',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierski/gbfs'},
#              {'id': 'tierstavanger',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tierstavanger/gbfs'},
#              {'id': 'tiertrondheim',
#               'url': 'https://api.entur.io/mobility/v2/gbfs/tiertrondheim/gbfs'}]}

# %%
r = rq.get("https://api.entur.io/mobility/v2/gbfs/tieroslo/gbfs")
pprint(json.loads(r.content))
# Out:
# {'data': {'nb': {'feeds': [{'name': 'system_information',
#                             'url': 'https://api.entur.io/mobility/v2/gbfs/tieroslo/system_information'},
#                            {'name': 'free_bike_status',
#                             'url': 'https://api.entur.io/mobility/v2/gbfs/tieroslo/free_bike_status'},
#                            {'name': 'vehicle_types',
#                             'url': 'https://api.entur.io/mobility/v2/gbfs/tieroslo/vehicle_types'},
#                            {'name': 'system_pricing_plans',
#                             'url': 'https://api.entur.io/mobility/v2/gbfs/tieroslo/system_pricing_plans'},
#                            {'name': 'geofencing_zones',
#                             'url': 'https://api.entur.io/mobility/v2/gbfs/tieroslo/geofencing_zones'}]}},
#  'last_updated': 1633265274,
#  'ttl': 300,
#  'version': '2.2'}

# %%
r = rq.get("https://api.entur.io/mobility/v2/gbfs/tieroslo/free_bike_status")
response = json.loads(r.content)

# %%
from utils import keysofkeys
keysofkeys(response)
# Out:
#  dict_keys(['last_updated', 'ttl', 'version', 'data'])
#  data dict_keys(['bikes'])
#  data bikes dict_keys(['bike_id', 'lat', 'lon', 'is_reserved', 'is_disabled', 'vehicle_type_id', 'rental_uris', 'current_range_meters', 'pricing_plan_id'])
#  data bikes rental_uris dict_keys(['android', 'ios'])

# %%
bike_details = [(b['lon'], b['lat'], b['current_range_meters'], b['is_reserved'], b['is_disabled']) for b in response['data']['bikes']]
df = pd.DataFrame(bike_details, columns=("lon", "lat", "range", "is_reserved", "is_disabled"))
df
# Out:
#            lon        lat    range  is_reserved  is_disabled
# 0    10.729690  59.939688  12948.0        False        False
# 1    10.772447  59.903090  30544.0        False        False
# 2    10.771564  59.942575  30544.0        False        False
# 3    10.754718  59.912372   1992.0        False        False
# 4    10.775808  59.935928  12616.0        False        False
# ..         ...        ...      ...          ...          ...
# 639  10.643617  59.931755  30544.0        False        False
# 640  10.729041  59.926829   4648.0        False        False
# 641  10.721270  59.937454  18592.0        False        False
# 642  10.765493  59.915013   4316.0        False        False
# 643  10.722161  59.910170  30544.0        False        False
#
# [644 rows x 5 columns]

# %%
import plotly.express as px
px.set_mapbox_access_token(open(".mapbox_token").read())
fig = px.scatter_mapbox(df, lat="lat", lon="lon", color="range", size="range",
                  color_continuous_scale=px.colors.sequential.Viridis, size_max=15, zoom=8, height=800)
fig.show()
# Out:
# <div>                            <div id="ddacf6c4-c3c4-4fe5-ba12-7de5293a93a8" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddacf6c4-c3c4-4fe5-ba12-7de5293a93a8")) {                    Plotly.newPlot(                        "ddacf6c4-c3c4-4fe5-ba12-7de5293a93a8",                        [{"hovertemplate":"range=%{marker.color}<br>lat=%{lat}<br>lon=%{lon}<extra></extra>","lat":[59.939688,59.90309,59.942575,59.912372,59.935928,59.930622,59.926889,59.955473,59.930519,59.912745,59.9457,59.91263,59.937864,59.940735,59.909879,59.918896,59.930556,59.93647,59.929603,59.923716,59.945929,59.913598,59.909632,59.925525,59.903947,59.92471,59.916409,59.911345,59.925927,59.923813,59.925102,59.925652,59.921269,59.934508,59.94079,59.899524,59.948085,59.919789,59.916329,59.927674,59.930723,59.937594,59.940613,59.946497,0.0,59.920964,59.914757,59.920171,59.962448,59.913632,59.92129,59.940803,0.0,59.901471,59.936769,59.952588,59.902006,59.907763,59.917